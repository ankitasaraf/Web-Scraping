# %% [markdown]
# ## Webscraping for Trend Analysis - Zomato

# %%
# Dependencies
import tweepy                                # twitter api
import pandas as pd                          # data analysis (dataframes, read file)
import numpy as np                           # arrays and linear algebra
import csv
from IPython.display import display          # print output in tabular format
import matplotlib.pyplot as plt              # for 2D plotting
from bokeh.plotting import figure            # library to create a new figure for plotting
from bokeh.io import show, output_notebook   # Configure the output state to output in notebook cells
import nltk
#%matplotlib inline                          # for plotting inline (next to the code)

# %%
## Twitter Credentials

# 1) Go to apps.twitter.com
# 2) Create a twitter app
# 3) Get the following 4 credentials from the app

consumerkey       = 'O31ZY4u61OBVeMKEpJP2MjiWi'  #You have to get your own keys.
consumersecret    = 'ikU8T3WKNraDfdBeOMm72iSp37lY6pJIVCQTqyTVufzfFw4hTb'
accesstoken       = '915505858972336128-QESfsNJ7Jt5D9uAYqOX8uJQIXEfQoyL'
accesstokensecret = 'KUR9pNmCwdSkqjN8Ok0LMDJN6KJQUeI4RQj7Y5gBASfgP'

# %%
#Establish connection with Twitter

auth = tweepy.OAuthHandler(consumerkey, consumersecret)  # passing consumerkey and consumersecret as paramaters to OAuthHandler attribute
auth.set_access_token(accesstoken, accesstokensecret)   # passing accesstoken and accesstokensecret as parameters to set_access_token
api = tweepy.API(auth,wait_on_rate_limit=True)             # establishing connection using all the credentials

# %%
# Open/Create a file to append data
csvFile = open('zomato.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)


#Data for common cryptocurrency hashtags
q='#zomato'
for tweet in tweepy.Cursor(api.search,q,
                           lang="en",
                           since="2020-06-01").items():
        print (tweet.text,tweet.created_at,tweet.favorite_count,tweet.retweet_count,q)
        csvWriter.writerow([tweet.text.encode('utf-8'),tweet.created_at, tweet.favorite_count,tweet.retweet_count,q])
csvFile.close()
# Out:
# @bharatjain1973 @ZomatoIN @zomatocare @Zomato Any solution or update @ZomatoIN @zomatocare @ZomatoIN ??? #zomato 2020-06-21 06:00:09 0 0 #zomato
# #Amazon &amp; #BigBasket have secured permit to deliver alcohol in India, in the country's fourth most populous state W… https://t.co/zPijX3AOPR 2020-06-21 05:47:03 0 0 #zomato
# This Father's Day, treat your father with a delicious meal with all his favorites from Combo Jumbo.… https://t.co/ef32LwL9fg 2020-06-21 05:43:26 0 0 #zomato
# #BoycottChina
# Let's first stop using #Flipkart, #Snapdeal, #Myntra #Zomato, #Byjus #Bigbasket, #Swiggy, #Paytm,… https://t.co/RJQW4PWzPN 2020-06-21 05:17:07 0 0 #zomato
# Dilli6 Ke Paranthe
# Ghar Jaisa Khana..
# Meal for 2@Rs.250/- Only
# #dilli6onwheels
# #dilli6onwheels_jiasarai
# With 2 Ou… https://t.co/NphAOYTRyT 2020-06-21 05:05:05 0 0 #zomato
# Chicken Curry Combo
# Ghar Jaisa Khana..
# Meal for 2@Rs.250/- Only
# #dilli6onwheels
# #dilli6onwheels_jiasarai
# ...

# %%
#Read csv file into dataframe

zomato_tweet = pd.read_csv('zomato.csv', names = ["Tweets","Date","Likes","Retweets","Hashtag"])
print (zomato_tweet.head(10))
# Out:
#                                               Tweets                 Date  \
# 0  b'@bharatjain1973 @ZomatoIN @zomatocare @Zomat...  2020-06-21 06:00:09
# 1  b"#Amazon &amp; #BigBasket have secured permit...  2020-06-21 05:47:03
# 2  b"This Father's Day, treat your father with a ...  2020-06-21 05:43:26
# 3  b"#BoycottChina\nLet's first stop using #Flipk...  2020-06-21 05:17:07
# 4  b'Dilli6 Ke Paranthe \nGhar Jaisa Khana..\nMea...  2020-06-21 05:05:05
# 5  b'Chicken Curry Combo\nGhar Jaisa Khana..\nMea...  2020-06-21 05:01:32
# 6  b'RT @HSuperdeluxe: Happy Father\xe2\x80\x99s ...  2020-06-21 04:40:21
# 7  b'Happy Father\xe2\x80\x99s Day to the First B...  2020-06-21 04:40:01
# 8  b'"\xe2\x80\x98If you\xe2\x80\x99re happy and ...  2020-06-21 04:32:01
# 9  b'@bikaneribhujia I placed an order for chat  ...  2020-06-20 19:49:31
#
#    Likes  Retweets  Hashtag
# 0      0         0  #zomato
# 1      0         0  #zomato
# 2      0         0  #zomato
# 3      0         0  #zomato
# ...

# %%
## Cleaning and Sentiment Analysis of the Tweet

from textblob import TextBlob                    # library for processing textual data          
import re

def clean_tweet(tweet):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
    

def get_polarity(tweet):                         # getting the polarity of each tweet after analysing it
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:          #polarity tells whether the tweet is postive/ negative/ neutral
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
zomato_tweet['Sentiment'] = np.array([ get_polarity(tweet) for tweet in zomato_tweet['Tweets'] ])

# %%
## Print top 10 tweets and check Sentiment field added
print(zomato_tweet.head(10))
# Out:
#                                               Tweets                 Date  \
# 0  b'@bharatjain1973 @ZomatoIN @zomatocare @Zomat...  2020-06-21 06:00:09
# 1  b"#Amazon &amp; #BigBasket have secured permit...  2020-06-21 05:47:03
# 2  b"This Father's Day, treat your father with a ...  2020-06-21 05:43:26
# 3  b"#BoycottChina\nLet's first stop using #Flipk...  2020-06-21 05:17:07
# 4  b'Dilli6 Ke Paranthe \nGhar Jaisa Khana..\nMea...  2020-06-21 05:05:05
# 5  b'Chicken Curry Combo\nGhar Jaisa Khana..\nMea...  2020-06-21 05:01:32
# 6  b'RT @HSuperdeluxe: Happy Father\xe2\x80\x99s ...  2020-06-21 04:40:21
# 7  b'Happy Father\xe2\x80\x99s Day to the First B...  2020-06-21 04:40:01
# 8  b'"\xe2\x80\x98If you\xe2\x80\x99re happy and ...  2020-06-21 04:32:01
# 9  b'@bikaneribhujia I placed an order for chat  ...  2020-06-20 19:49:31
#
#    Likes  Retweets  Hashtag  Sentiment
# 0      0         0  #zomato          0
# 1      0         0  #zomato          1
# ...

# %%
## Classifying the tweets

positive_tweets = [ tweet for index, tweet in enumerate(zomato_tweet['Tweets']) if zomato_tweet['Sentiment'][index] > 0]
neutral_tweets = [ tweet for index, tweet in enumerate(zomato_tweet['Tweets']) if zomato_tweet['Sentiment'][index] == 0]
negative_tweets = [ tweet for index, tweet in enumerate(zomato_tweet['Tweets']) if zomato_tweet['Sentiment'][index] < 0]      

positive_data = pd.DataFrame (data = [ tweet for index, tweet in enumerate(zomato_tweet['Tweets']) if zomato_tweet['Sentiment'][index] > 0])
neutral_data = [ tweet for index, tweet in enumerate(zomato_tweet['Tweets']) if zomato_tweet['Sentiment'][index] == 0]
negative_data = [ tweet for index, tweet in enumerate(zomato_tweet['Tweets']) if zomato_tweet['Sentiment'][index] < 0]

# %%
print (positive_data.shape)
# Out:
# (275, 1)

# %%
positive_data.columns
# Out:
# Index(['Text'], dtype='object')

# %%
positive_data.head
# Out:
# <bound method NDFrame.head of                                                   Text
# 0    b"#Amazon &amp; #BigBasket have secured permit...
# 1    b"This Father's Day, treat your father with a ...
# 2    b"#BoycottChina\nLet's first stop using #Flipk...
# 3    b'RT @HSuperdeluxe: Happy Father\xe2\x80\x99s ...
# 4    b'Happy Father\xe2\x80\x99s Day to the First B...
# ..                                                 ...
# 270  b'RT @CafeCoffeeDay: Feel amazingly refreshed ...
# 271  b'RT @PepPure: Hello Kolkata! Here we come! Ex...
# 272  b'RT @PepPure: Hello Kolkata! Here we come! Ex...
# 273  b'Kornish Multicuisone Restaurant\n \n#zomato ...
# 274  b'RT @PepPure: Hello Kolkata! Here we come! Ex...
#
# [275 rows x 1 columns]>

# %%
sentiment_count = zomato_tweet['Sentiment'].value_counts()
sentiment_count
# Out:
#  0    370
#  1    275
# -1    126
# Name: Sentiment, dtype: int64

# %%
#Visualization of sentiment of tweets

size = [len(positive_tweets), len(negative_tweets), len(neutral_tweets)]
colors = ['yellow', 'red', 'cyan']
labels = 'Positive', 'Negative', 'Neutral'

plt.pie(
   x=size,
   colors=colors,
   labels=labels,
   startangle=45
)
plt.show()

# %%
# Print a tweet and its sentiment to check whether analysis is correct

zomato_tweet["Tweets"][9]
# Out:
# "b'@bikaneribhujia I placed an order for chat  with you through @ZomatoIN Kolkata,I am not satisfied with taste but I\\xe2\\x80\\xa6 https://t.co/qY5vLndfso'"

# %%
zomato_tweet["Sentiment"][9]
# Out:
# -1

# %%
positive_data.columns = ['Text']

# %%
import string
from collections import Counter
from nltk.tokenize import TweetTokenizer #specially to handle tweets into documents
from nltk.corpus import stopwords # to remove stop words
import nltk
nltk.download('stopwords')
from nltk.corpus import wordnet

def process(text, tokenizer=TweetTokenizer(), stopwords=[]):
    #text = text.lower() # for normalization
    text = ' '.join(text).lower()
    tokens = tokenizer.tokenize(text)
    return [t for t in tokens if not t in stopwords and not t.isdigit()]

tweet_tokenizer = TweetTokenizer()
punct = list(string.punctuation)
stopword_list = stopwords.words('english') + punct + ['b','n','co','get','new','us','join','versaratrade','rt','via', '...','b\'rt','https','#versaratrade','@versaratrade','@', '#', 'amp', 'http', '/', '://', '_',]
tf = Counter()
tokens = process(text=positive_data['Text'],tokenizer=tweet_tokenizer,stopwords=stopword_list)
tf.update(tokens)
for tag, count in tf.most_common(50):
        print("{}: {}".format(tag, count))
# Out:
# xe2: 306
# x80: 294
# xa6: 262
# #zomato: 85
# xf0: 77
# x9f: 77
# food: 41
# @zomato: 37
# order: 36
# many: 34
# #swiggy: 32
# zomato: 30
# chinese: 28
# delivery: 28
# x91: 26
# indian: 26
# x8f: 22
# want: 22
# also: 22
# @zomatoin: 21
# public: 20
# #bycottchina: 20
# backed: 20
# companies: 20
# home: 19
# x8d: 18
# available: 17
# right: 17
# delicious: 16
# x99s: 16
# x98: 15
# delivered: 15
# india: 14
# first: 14
# #paytm: 14
# good: 13
# service: 13
# xa4: 12
# favourite: 12
# @zomatocare: 12
# online: 12
# make: 12
# best: 11
# xbb: 11
# b'the: 11
# happy: 10
# know: 10
# really: 10
# enjoy: 10
# swiggy: 10
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ankita\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import matplotlib.pyplot as plt
y = [count for tag, count in tf.most_common(100)]
x = range(1, len(y)+1)
plt.bar(x, y)
plt.title("Term Frequencies")
plt.ylabel("Frequency")

#There are a few words with very high frequency and then the plots are almost of the same height.
#This indicates that there are few words that are very commonly used in tweets.
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#from wordcloud import *
from nltk.tokenize import wordpunct_tokenize
from subprocess import check_output

def process(text, tokenizer=TweetTokenizer(), stopwords=[]):
    text = ' '.join(text).lower()
    tokens = tokenizer.tokenize(text)
    return [tok for tok in tokens if not tok in stopwords and not tok.isdigit()]

tweet_tokenizer = TweetTokenizer()
punct = list(string.punctuation)
stopword_list = stopwords.words('english') + punct + ['b','n','co','versaratrade','get','new','us','join','rt','via', '...','b\'rt','https','#versaratrade','@versaratrade','@', '#', 'amp', 'http', '/', '://', '_',]
series_tweets = positive_data['Text']
tweet_str = series_tweets.str.cat(sep = ' ')
list_of_words = [i.lower() for i in wordpunct_tokenize(tweet_str) if i.lower() not in stopword_list and i.isalpha()]
wordfreqdist = nltk.FreqDist(list_of_words)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)
# Out:
# [('zomato', 162), ('food', 44), ('swiggy', 42), ('order', 36), ('many', 34), ('delivery', 30), ('chinese', 28), ('indian', 26), ('want', 22), ('also', 22), ('zomatoin', 21), ('home', 21), ('public', 20), ('bycottchina', 20), ('backed', 20), ('companies', 20), ('delicious', 18), ('available', 17), ('right', 17), ('india', 16), ('paytm', 16), ('enjoy', 16), ('delivered', 15), ('first', 14), ('online', 14), ('good', 13), ('service', 13), ('happy', 12), ('favourite', 12), ('dear', 12), ('zomatocare', 12), ('china', 12), ('make', 12), ('best', 11), ('xbb', 11), ('take', 11), ('much', 11), ('father', 10), ('know', 10), ('really', 10), ('favorite', 10), ('menu', 10), ('uninstalling', 10), ('startups', 10), ('marriott', 9), ('day', 8), ('xef', 8), ('fathersday', 8), ('declaremaharashtracabratesdear', 8), ('norder', 8)]

# %%
mostcom = str(mostcommon)

data_new = pd.DataFrame(mostcommon, columns = ['word','frequency'])

data_new.head(10)
# Out:
#        word  frequency
# 0    zomato        162
# 1      food         44
# 2    swiggy         42
# 3     order         36
# 4      many         34
# 5  delivery         30
# 6   chinese         28
# 7    indian         26
# 8      want         22
# 9      also         22

# %%
plt.barh(range(len(mostcommon)),[val[1] for val in mostcommon], align='center')
plt.yticks(range(len(mostcommon)), [val[0] for val in mostcommon])
plt.show()

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(max_font_size=60
                      , background_color="white"
                      , stopwords=stopword_list
                      , collocations=False).generate(mostcom)

# Display the generated image with matplotlib 
plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.title('Positive Sentiments Word Cloud')
plt.savefig("wordcloud.png")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
